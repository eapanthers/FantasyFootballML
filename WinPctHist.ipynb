# %%
import warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from operator import itemgetter

# %%
dfWinPct = pd.read_csv('final-csv-data/WinPct.csv')

dfStandings = pd.read_csv('teamWinPct/Standings.csv')
dfStandings.head()
# Out:
# C:\Users\Eric\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Unnamed: 0  Average Wins  Difference (Larger = worse luck)  \
# 0  Cardinals      3.805348                          0.805348
# 1    Raiders      5.023123                          1.023123
# 2       Jets      5.241501                          1.241501
# 3      Bills      5.346536                         -0.653464
# 4     Browns      5.562552                         -1.937448
#
#    Standard Deviation  Unnamed: 4
# 0            0.258611    4.345348
# 1            0.282595    5.563123
# 2            0.312286    5.781501
# 3            0.350028    5.886536
# 4            0.304744    6.102552

# %%
Cardinals = dfWinPct.iloc[0,1:]
Cardinals = Cardinals.astype(float)
Falcons = dfWinPct.iloc[1,1:]
Falcons = Falcons.astype(float)
Ravens = dfWinPct.iloc[2,1:]
Ravens = Ravens.astype(float)
Bills = dfWinPct.iloc[3,1:]
Bills = Bills.astype(float)
Panthers = dfWinPct.iloc[4,1:]
Panthers = Panthers.astype(float)
Bears = dfWinPct.iloc[5,1:]
Bears = Bears.astype(float)
Bengals = dfWinPct.iloc[6,1:]
Bengals = Bengals.astype(float)
Browns = dfWinPct.iloc[7,1:]
Browns = Browns.astype(float)
Cowboys = dfWinPct.iloc[8,1:]
Cowboys = Cowboys.astype(float)
Broncos = dfWinPct.iloc[9,1:]
Broncos = Broncos.astype(float)
Lions = dfWinPct.iloc[10,1:]
Lions = Lions.astype(float)
Packers = dfWinPct.iloc[11,1:]
Packers = Packers.astype(float)
Texans = dfWinPct.iloc[12,1:]
Texans = Texans.astype(float)
Colts = dfWinPct.iloc[13,1:]
Colts = Colts.astype(float)
Jags = dfWinPct.iloc[14,1:]
Jags = Jags.astype(float)
Chiefs = dfWinPct.iloc[15,1:]
Chiefs = Chiefs.astype(float)
Chargers = dfWinPct.iloc[16,1:]
Chargers = Chargers.astype(float)
Rams = dfWinPct.iloc[17,1:]
Rams = Rams.astype(float)
Dolphins = dfWinPct.iloc[18,1:]
Dolphins = Dolphins.astype(float)
Vikings = dfWinPct.iloc[19,1:]
Vikings = Vikings.astype(float)
Patriots = dfWinPct.iloc[20,1:]
Patriots = Patriots.astype(float)
Saints = dfWinPct.iloc[21,1:]
Saints = Saints.astype(float)
Giants = dfWinPct.iloc[22,1:]
Giants = Giants.astype(float)
Jets = dfWinPct.iloc[23,1:]
Jets = Jets.astype(float)
Raiders = dfWinPct.iloc[24,1:]
Raiders = Raiders.astype(float)
Eagles = dfWinPct.iloc[25,1:]
Eagles = Eagles.astype(float)
Steelers = dfWinPct.iloc[26,1:]
Steelers = Steelers.astype(float)
SanFran = dfWinPct.iloc[27,1:]
SanFran = SanFran.astype(float)
Seahawks = dfWinPct.iloc[28,1:]
Seahawks = Seahawks.astype(float)
Bucs = dfWinPct.iloc[29,1:]
Bucs = Bucs.astype(float)
Titans = dfWinPct.iloc[30,1:]
Titans = Titans.astype(float)
Redskins = dfWinPct.iloc[31,1:]
Redskins = Redskins.astype(float)
NFL = dfWinPct.iloc[34,1:]
NFL = NFL.astype(float)
Panthers2017 = dfWinPct.iloc[32,1:]
Panthers2017 = Panthers2017.astype(float)
Panthers2016 = dfWinPct.iloc[33,1:]
Panthers2016 = Panthers2016.astype(float)

# %%
Cardinals.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#97233F')
rpString = "hi"
plt.title('Arizona Cardinals Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Cardinals.plot.kde(ax=ax, legend=False,color='#FFB612')
Cardinals.plot.hist(density=True, ax=ax,color='#97233F',bins=30)
fig.suptitle("Arizona Cardinals Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Cardinals.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/CardinalsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Falcons.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#A71930')

plt.title('Atlanta Falcons Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Falcons.plot.kde(ax=ax, legend=False,color='#000000')
Falcons.plot.hist(density=True, ax=ax,color='#A71930',bins=30)
fig.suptitle("Atlanta Falcons Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Falcons.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/FalconsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Ravens.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#241773')

plt.title('Baltimore Ravens Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Ravens.plot.kde(ax=ax, legend=False,color='#9E7C0C')
Ravens.plot.hist(density=True, ax=ax,color='#241773',bins=30)
fig.suptitle("Baltimore Ravens Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Ravens.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/RavensHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Bills.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#00338D')

plt.title('Buffalo Bills Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Bills.plot.kde(ax=ax, legend=False,color='#C60C30')
Bills.plot.hist(density=True, ax=ax,color='#00338D',bins=30)
fig.suptitle("Buffalo Bills Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Bills.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/BillsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Panthers.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#0085CA')

plt.title('Carolina Panthers Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Panthers.plot.kde(ax=ax, legend=False,color='#101820')
Panthers.plot.hist(density=True, ax=ax,color='#0085CA',bins=30)
fig.suptitle("Carolina Panthers Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Panthers.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/PanthersHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Bears.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#0B162A')

plt.title('Chicago Bears Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Bears.plot.kde(ax=ax, legend=False,color='#C83803')
Bears.plot.hist(density=True, ax=ax,color='#0B162A',bins=30)
fig.suptitle("Chicago Bears Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Bears.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/BearsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots()
plt.xlim(-0.1,1.1)
Bears.plot.kde(ax=ax, legend=False,color='#C83803', label="Bears")
Panthers.plot.kde(ax=ax, legend=False,color='#BFC0BF', label="Panthers")
Bills.plot.kde(ax=ax, legend=False,color='#C60C30', label="Bills")
Ravens.plot.kde(ax=ax, legend=False,color='#9E7C0C', label="Ravens")
Falcons.plot.kde(ax=ax, legend=False,color='#000000', label="Falcons")
Cardinals.plot.kde(ax=ax, legend=False,color='#FFB612', label="Cardinals")
ax.legend(loc='best', prop={'size':9, "family":"DejaVu Sans"})
fig.suptitle("Combined Probability Density Functions")
#fig.savefig('teamWinPct/TotalSmooth.png', dpi = 400, bbox_inches = 'tight')

# %%
Bengals.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#000000')

plt.title('Cincinnati Bengals Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Bengals.plot.kde(ax=ax, legend=False,color='#FB4F14')
Bengals.plot.hist(density=True, ax=ax,color='#000000',bins=30)
fig.suptitle("Cincinnati Bengals Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Bengals.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/BengalsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Browns.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#311D00')

plt.title('Cleveland Browns Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Browns.plot.kde(ax=ax, legend=False,color='#FF3C00')
Browns.plot.hist(density=True, ax=ax,color='#311D00',bins=30)
fig.suptitle("Cleveland Browns Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Browns.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/BrownsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots()
plt.xlim(-0.1,1.1)
Bears.plot.kde(ax=ax, legend=False,color='#C83803', label="Bears")
Panthers.plot.kde(ax=ax, legend=False,color='#BFC0BF', label="Panthers")
Bills.plot.kde(ax=ax, legend=False,color='#C60C30', label="Bills")
Ravens.plot.kde(ax=ax, legend=False,color='#9E7C0C', label="Ravens")
Falcons.plot.kde(ax=ax, legend=False,color='#000000', label="Falcons")
Cardinals.plot.kde(ax=ax, legend=False,color='#FFB612', label="Cardinals")
Bengals.plot.kde(ax=ax, legend=False,color='#FB4F14', label="Bengals")
Browns.plot.kde(ax=ax, legend=False,color='#FF3C00', label="Browns")
ax.legend(loc='best', prop={'size':5, "family":"DejaVu Sans"})
fig.suptitle("Combined Probability Density Functions")
#fig.savefig('teamWinPct/TotalSmooth.png', dpi = 400, bbox_inches = 'tight')

# %%
Cowboys.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#041E42')

plt.title('Dallas Cowboys Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Cowboys.plot.kde(ax=ax, legend=False,color='#869397')
Cowboys.plot.hist(density=True, ax=ax,color='#041E42',bins=30)
fig.suptitle("Dallas Cowboys Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Cowboys.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/CowboysHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Broncos.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#FB4F14')

plt.title('Denver Broncos Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Broncos.plot.kde(ax=ax, legend=False,color='#002244')
Broncos.plot.hist(density=True, ax=ax,color='#FB4F14',bins=30)
fig.suptitle("Denver Broncos Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Broncos.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/BroncosHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Lions.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#B0B7BC')

plt.title('Detroit Lions Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Lions.plot.kde(ax=ax, legend=False,color='#0076B6')
Lions.plot.hist(density=True, ax=ax,color='#B0B7BC',bins=30)
fig.suptitle("Detroit Lions Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Lions.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/LionsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Packers.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#203731')

plt.title('Green Bay Packers Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Packers.plot.kde(ax=ax, legend=False,color='#FFB612')
Packers.plot.hist(density=True, ax=ax,color='#203731',bins=30)
fig.suptitle("Green Bay Packers Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Packers.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/PackersHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Texans.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#03202F')

plt.title('Houston Texans Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Texans.plot.kde(ax=ax, legend=False,color='#A71930')
Texans.plot.hist(density=True, ax=ax,color='#03202F',bins=30)
fig.suptitle("Houston Texans Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Texans.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/TexansHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Colts.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#002C5F')

plt.title('Indianapolis Colts Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Colts.plot.kde(ax=ax, legend=False,color='#A2AAAD')
Colts.plot.hist(density=True, ax=ax,color='#002C5F',bins=30)
fig.suptitle("Indianapolis Colts Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Colts.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/ColtsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Jags.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#006778')

plt.title('Jacksonville Jaguars Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Jags.plot.kde(ax=ax, legend=False,color='#D7A22A')
Jags.plot.hist(density=True, ax=ax,color='#006778',bins=30)
fig.suptitle("Jacksonville Jaguars Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Jags.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/JaguarsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Chiefs.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#E31837')

plt.title('Kansas City Chiefs Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Chiefs.plot.kde(ax=ax, legend=False,color='#FFB81C')
Chiefs.plot.hist(density=True, ax=ax,color='#E31837',bins=30)
fig.suptitle("Kansas City Chiefs Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Chiefs.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/ChiefsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Chargers.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#002A5E')

plt.title('Los Angeles Chargers Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Chargers.plot.kde(ax=ax, legend=False,color='#FFC20E')
Chargers.plot.hist(density=True, ax=ax,color='#002A5E',bins=30)
fig.suptitle("Los Angeles Chargers Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Chargers.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/ChargersHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Rams.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#002244')

plt.title('Los Angeles Rams Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Rams.plot.kde(ax=ax, legend=False,color='#866D4B')
Rams.plot.hist(density=True, ax=ax,color='#002244',bins=30)
fig.suptitle("Los Angeles Rams Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Rams.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/RamsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Dolphins.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#F26A24')

plt.title('Miami Dolphins Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Dolphins.plot.kde(ax=ax, legend=False,color='#008E97')
Dolphins.plot.hist(density=True, ax=ax,color='#F26A24',bins=30)
fig.suptitle("Miami Dolphins Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Dolphins.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/DolphinsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Vikings.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#FFC62F')

plt.title('Minnesota Vikings Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Vikings.plot.kde(ax=ax, legend=False,color='#4F2683')
Vikings.plot.hist(density=True, ax=ax,color='#FFC62F',bins=30)
fig.suptitle("Minnesota Vikings Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Vikings.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/VikingsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Patriots.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#002244')

plt.title('New England Patriots Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Patriots.plot.kde(ax=ax, legend=False,color='#C60C30')
Patriots.plot.hist(density=True, ax=ax,color='#002244',bins=30)
fig.suptitle("New England Patriots Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Patriots.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/PatriotsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Saints.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#101820')

plt.title('New Orleans Saints Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Saints.plot.kde(ax=ax, legend=False,color='#D3BC8D')
Saints.plot.hist(density=True, ax=ax,color='#101820',bins=30)
fig.suptitle("New Orleans Saints Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Saints.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/SaintsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Giants.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#0B2265')

plt.title('New York Giants Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Giants.plot.kde(ax=ax, legend=False,color='#A71930')
Giants.plot.hist(density=True, ax=ax,color='#0B2265',bins=30)
fig.suptitle("New York Giants Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Giants.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/GiantsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Jets.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#DCDCDC')

plt.title('New York Jets Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Jets.plot.kde(ax=ax, legend=False,color='#003F2D')
Jets.plot.hist(density=True, ax=ax,color='#DCDCDC',bins=30)
fig.suptitle("New York Jets Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Jets.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/JetsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Raiders.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#000000')

plt.title('Oakland Raiders Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Raiders.plot.kde(ax=ax, legend=False,color='#A5ACAF')
Raiders.plot.hist(density=True, ax=ax,color='#000000',bins=30)
fig.suptitle("Oakland Raiders Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Raiders.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/RaidersHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Eagles.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#A5ACAF')

plt.title('Philadelphia Eagles Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Eagles.plot.kde(ax=ax, legend=False,color='#004C54')
Eagles.plot.hist(density=True, ax=ax,color='#A5ACAF',bins=30)
fig.suptitle("Philadelphia Eagles Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Eagles.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/EaglesHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Steelers.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#101820')

plt.title('Pittsburgh Steelers Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Steelers.plot.kde(ax=ax, legend=False,color='#FFB612')
Steelers.plot.hist(density=True, ax=ax,color='#101820',bins=30)
fig.suptitle("Pittsburgh Steelers Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Steelers.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/SteelersHist.png', dpi = 400, bbox_inches = 'tight')

# %%
SanFran.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#AA0000')

plt.title('San Francisco 49ers Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
SanFran.plot.kde(ax=ax, legend=False,color='#B3995D')
SanFran.plot.hist(density=True, ax=ax,color='#AA0000',bins=30)
fig.suptitle("San Francisco 49ers Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%SanFran.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/49ersHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Seahawks.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#002244')

plt.title('Seattle Seahawks Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Seahawks.plot.kde(ax=ax, legend=False,color='#69BE28')
Seahawks.plot.hist(density=True, ax=ax,color='#002244',bins=30)
fig.suptitle("Seattle Seahawks Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Seahawks.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/SeahawksHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Bucs.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#D50A0A')

plt.title('Tampa Bay Buccaneers Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Bucs.plot.kde(ax=ax, legend=False,color='#FF7900')
Bucs.plot.hist(density=True, ax=ax,color='#D50A0A',bins=30)
fig.suptitle("Tampa Bay Buccaneers Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Bucs.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/BucsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Titans.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#0C2340')

plt.title('Tennessee Titans Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Titans.plot.kde(ax=ax, legend=False,color='#418FDE')
Titans.plot.hist(density=True, ax=ax,color='#0C2340',bins=30)
fig.suptitle("Tennessee Titans Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Titans.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/TitansHist.png', dpi = 400, bbox_inches = 'tight')

# %%
Redskins.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#773141')

plt.title('Washington Redskins Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Redskins.plot.kde(ax=ax, legend=False,color='#FFB612')
Redskins.plot.hist(density=True, ax=ax,color='#773141',bins=30)
fig.suptitle("Washington Redskins Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Redskins.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/RedskinsHist.png', dpi = 400, bbox_inches = 'tight')

# %%
NFL.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#013369')

plt.title('NFL Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
NFL.plot.kde(ax=ax, legend=False,color='#d50a0a')
NFL.plot.hist(density=True, ax=ax,color='#013369',bins=30)
fig.suptitle("NFL Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%NFL.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/NFLHist.png', dpi = 400, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots()
plt.xlim(-0.1,1.1)
Bears.plot.kde(ax=ax, legend=False,color='#C83803', label="Bears")
Panthers.plot.kde(ax=ax, legend=False,color='#BFC0BF', label="Panthers")
Bills.plot.kde(ax=ax, legend=False,color='#C60C30', label="Bills")
Ravens.plot.kde(ax=ax, legend=False,color='#9E7C0C', label="Ravens")
Falcons.plot.kde(ax=ax, legend=False,color='#000000', label="Falcons")
Cardinals.plot.kde(ax=ax, legend=False,color='#FFB612', label="Cardinals")
Bengals.plot.kde(ax=ax, legend=False,color='#FB4F14', label="Bengals")
Browns.plot.kde(ax=ax, legend=False,color='#FF3C00', label="Browns", style="--")
Redskins.plot.kde(ax=ax, legend=False,color='#FFB612', label="Redskins")
Titans.plot.kde(ax=ax, legend=False,color='#418FDE', label="Titans")
Bucs.plot.kde(ax=ax, legend=False,color='#FF7900', label="Bucs")
Seahawks.plot.kde(ax=ax, legend=False,color='#69BE28', label="Seahawks")
SanFran.plot.kde(ax=ax, legend=False,color='#B3995D', label="49ers")
Steelers.plot.kde(ax=ax, legend=False,color='#FFB612', label="Steelers", style="-.")
Eagles.plot.kde(ax=ax, legend=False,color='#004C54', label="Eagles")
Raiders.plot.kde(ax=ax, legend=False,color='#A5ACAF', label="Raiders")
Jets.plot.kde(ax=ax, legend=False,color='#003F2D', label="Jets")
Giants.plot.kde(ax=ax, legend=False,color='#A71930', label="Giants", style=":")
Saints.plot.kde(ax=ax, legend=False,color='#D3BC8D', label="Saints")
Patriots.plot.kde(ax=ax, legend=False,color='#C60C30', label="Patriots", style="-.")
Vikings.plot.kde(ax=ax, legend=False,color='#4F2683', label="Vikings")
Dolphins.plot.kde(ax=ax, legend=False,color='#008E97', label="Dolphins")
Rams.plot.kde(ax=ax, legend=False,color='#866D4B', label="Rams")
Chargers.plot.kde(ax=ax, legend=False,color='#FFC20E', label="Chargers", style="--")
Chiefs.plot.kde(ax=ax, legend=False,color='#FFB81C', label="Chiefs", style=":")
Jags.plot.kde(ax=ax, legend=False,color='#D7A22A', label="Jaguars")
Colts.plot.kde(ax=ax, legend=False,color='#A2AAAD', label="Colts")
Texans.plot.kde(ax=ax, legend=False,color='#A71930', label="Texans", style="--")
Packers.plot.kde(ax=ax, legend=False,color='#203731', label="Packers")
Lions.plot.kde(ax=ax, legend=False,color='#0076B6', label="Lions")
Broncos.plot.kde(ax=ax, legend=False,color='#002244', label="Broncos")
Cowboys.plot.kde(ax=ax, legend=False,color='#869397', label="Cowboys", style="--")
ax.legend(loc='lower right', prop={'size':3, "family":"DejaVu Sans"}, fancybox = True)
fig.suptitle("Combined Probability Density Functions")
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/TotalSmooth.png', dpi = 400, bbox_inches = 'tight')

# %%
#Playoff Graph
fig, ax = plt.subplots()
plt.xlim(-0.1,1.1)
Bears.plot.kde(ax=ax, legend=False,color='#C83803', label="Bears")
Cowboys.plot.kde(ax=ax, legend=False,color='#869397', label="Cowboys", style="--")
Texans.plot.kde(ax=ax, legend=False,color='#A71930', label="Texans", style="--")
Rams.plot.kde(ax=ax, legend=False,color='#866D4B', label="Rams")
Colts.plot.kde(ax=ax, legend=False,color='#A2AAAD', label="Colts")
Chiefs.plot.kde(ax=ax, legend=False,color='#FFB81C', label="Chiefs", style=":")
Chargers.plot.kde(ax=ax, legend=False,color='#002A5E', label="Chargers")
Seahawks.plot.kde(ax=ax, legend=False,color='#69BE28', label="Seahawks")
Patriots.plot.kde(ax=ax, legend=False,color='#C60C30', label="Patriots")
Saints.plot.kde(ax=ax, legend=False,color='#D3BC8D', label="Saints")
Ravens.plot.kde(ax=ax, legend=False,color='#9E7C0C', label="Ravens")
Eagles.plot.kde(ax=ax, legend=False,color='#004C54', label="Eagles")
ax.legend(loc='best', prop={'size':5, "family":"DejaVu Sans"}, fancybox = True)
fig.suptitle("Combined Probability Density Functions")
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/PlayoffSmooth.png', dpi = 400, bbox_inches = 'tight')

# %%
#Bottom 10
fig, ax = plt.subplots()
plt.xlim(-0.1,1.1)
Cardinals.plot.kde(ax=ax, legend=False,color='#FFB612', label="Cardinals")
SanFran.plot.kde(ax=ax, legend=False,color='#B3995D', label="49ers")
Raiders.plot.kde(ax=ax, legend=False,color='#A5ACAF', label="Raiders")
Jets.plot.kde(ax=ax, legend=False,color='#003F2D', label="Jets")
Giants.plot.kde(ax=ax, legend=False,color='#A71930', label="Giants", style=":")
Bucs.plot.kde(ax=ax, legend=False,color='#FF7900', label="Bucs")
Jags.plot.kde(ax=ax, legend=False,color='#D7A22A', label="Jaguars")
Lions.plot.kde(ax=ax, legend=False,color='#0076B6', label="Lions")
Bills.plot.kde(ax=ax, legend=False,color='#C60C30', label="Bills")
Broncos.plot.kde(ax=ax, legend=False,color='#002244', label="Broncos")
ax.legend(loc='best', prop={'size':5, "family":"DejaVu Sans"}, fancybox = True)
fig.suptitle("Combined Probability Density Functions")
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/Bottom10Smooth.png', dpi = 400, bbox_inches = 'tight')

# %%
#Middle 10
fig, ax = plt.subplots()
plt.xlim(-0.1,1.1)
Bengals.plot.kde(ax=ax, legend=False,color='#FB4F14', label="Bengals")
Packers.plot.kde(ax=ax, legend=False,color='#203731', label="Packers")
Dolphins.plot.kde(ax=ax, legend=False,color='#008E97', label="Dolphins")
Falcons.plot.kde(ax=ax, legend=False,color='#000000', label="Falcons")
Redskins.plot.kde(ax=ax, legend=False,color='#FFB612', label="Redskins")
Panthers.plot.kde(ax=ax, legend=False,color='#BFC0BF', label="Panthers")
Browns.plot.kde(ax=ax, legend=False,color='#FF3C00', label="Browns", style="--")
Vikings.plot.kde(ax=ax, legend=False,color='#4F2683', label="Vikings")
Titans.plot.kde(ax=ax, legend=False,color='#418FDE', label="Titans")
Steelers.plot.kde(ax=ax, legend=False,color='#FFB612', label="Steelers", style="--")
ax.legend(loc='best', prop={'size':5, "family":"DejaVu Sans"}, fancybox = True)
fig.suptitle("Combined Probability Density Functions")
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/Middle10Smooth.png', dpi = 400, bbox_inches = 'tight')

# %%
fig,ax = plt.subplots()
ax.scatter(dfStandings['Average Wins'], dfStandings['Difference (Larger = worse luck)'], color = 'orange', label = "Running backs")

fig.suptitle("Correlation between expected wins and luck rating", weight = 'bold', size = 18, y = 1.05)
ax.set_xlabel("Expected Wins")
ax.set_ylabel("Luck Rating")

ax.plot(np.unique(dfStandings['Average Wins']), np.poly1d(np.polyfit(dfStandings['Average Wins'], dfStandings['Difference (Larger = worse luck)'],1))(np.unique(dfStandings['Average Wins'])))

# %%
Panthers2017.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#0085CA')

plt.title('Carolina Panthers 2017 Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Panthers2017.plot.kde(ax=ax, legend=False,color='#101820')
Panthers2017.plot.hist(density=True, ax=ax,color='#0085CA',bins=30)
fig.suptitle("Carolina Panthers 2017 Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Panthers2017.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/Panthers2017Hist.png', dpi = 400, bbox_inches = 'tight')

# %%
fig, ax = plt.subplots()
plt.xlim(-0.1,1.1)
Panthers2017.plot.kde(ax=ax, legend=False,color='#101820', label="Panthers2017")
Panthers.plot.kde(ax=ax,legend=False, color='#0085CA', label="Panthers")
Panthers2016.plot.kde(ax=ax, legend=False,color='#BFC0BF', label="Panthers2016")
ax.legend(loc='best', prop={'size':9, "family":"DejaVu Sans"}, fancybox = True)
fig.suptitle("Combined Probability Density Functions")
ax.set_xlabel("Probability of winning")
fig.savefig('teamWinPct/TeamPics/PanthersCombined.png', dpi = 400, bbox_inches = 'tight')

# %%
Panthers2016.plot.hist(grid=True, bins=50, rwidth=1,
                   color='#0085CA')

plt.title('Carolina Panthers 2016 Win Probabilities')
plt.xlabel('Win Probability')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)

# %%
fig, ax = plt.subplots()
Panthers2016.plot.kde(ax=ax, legend=False,color='#101820')
Panthers2016.plot.hist(density=True, ax=ax,color='#0085CA',bins=30)
fig.suptitle("Carolina Panthers 2016 Histogram")
plt.xlim(-0.1,1.1)
ax.set_title("Standard Deviation: %s"%Panthers2016.std(), size=10)
ax.set_ylabel('Frequency')
ax.grid(axis='y')
ax.set_facecolor('#ffffff')
ax.set_xlabel("Probability of winning")
#fig.savefig('teamWinPct/TeamPics/Panthers2016Hist.png', dpi = 400, bbox_inches = 'tight')
